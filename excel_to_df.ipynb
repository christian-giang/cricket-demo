# %%
import pandas as pd
import pickle

# %%
df_logs = pd.read_excel('data-test2.xlsx')
df_logs
# Out:
#        Time   Fighter       Action     Target  Speed      Hit    GIF
# 0  00:10:00  Chandler   Left punch       Head    5.5  Blocked  1.jpg
# 1  00:12:00  Chandler  Right punch       Head    4.4  Blocked  2.jpg
# 2  00:13:00  Chandler  Right punch       Head    5.2  Blocked  3.jpg
# 3  00:20:00  Chandler  Right punch       Body    4.6  Blocked  4.jpg
# 4  00:40:00   Gaethje  Right punch       Head    2.4  Blocked  5.jpg
# 5  00:41:00   Gaethje   Left punch       Head    1.5   Landed  6.jpg
# 6  00:59:00   Gaethje    Left kick  Lower leg    5.6   Landed  7.jpg
# 7  01:12:00  Chandler  Right punch       Body    5.2  Blocked  8.jpg
# 8  01:20:00   Gaethje   Left punch       Head    4.1   Evaded  9.jpg
